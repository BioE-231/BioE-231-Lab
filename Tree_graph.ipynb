# %%
from matplotlib import pyplot
from Bio import Phylo
tree = Phylo.read(open("tree.nwk"),"newick")
tree_plot = Phylo.draw(tree)
fig = pyplot.gcf()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-fb20c9f1d658> in <module>()
# ----> 1 fig = pyplot.gcf(tree_plot)
#
# TypeError: gcf() takes 0 positional arguments but 1 was given
